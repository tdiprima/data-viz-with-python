# %% [markdown]
# ## Here's my: Exploring the data without even looking at it (almost).

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. What've we got?
#
# ### List the csv files in a directory

# %%
import os
import fnmatch

# directory = '/path/to/directory'
directory = '.'

for file in os.listdir(directory):
    if fnmatch.fnmatch(file, '*.csv'):  # Check if the file has a .csv extension
        print(os.path.join(directory, file))  # Print the file path
# Out:
# ./gas_prices.csv
# ./fifa_data.csv

# %% [markdown]
# ## 2. Load CSV file into Pandas DataFrame

# %%
# Load CSV file into a Pandas DataFrame and get the file name
file_name = 'gas_prices.csv'
df_gas_prices = pd.read_csv(file_name)

# Print the file name
print("File name:", file_name)
# Out:
# File name: gas_prices.csv

# %% [markdown]
# ## 3. Print the first 5 rows

# %%
df_gas_prices.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %% [markdown]
# ## 4. Describe &ndash; even better. 👍

# %%
# Get descriptive statistics of the DataFrame
df_gas_prices.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %% [markdown]
# ## 5. Graph
#
# This data would do well with a line chart. 🕵️

# %%
# Create a line plot of gas prices versus year

# df_gas_prices.plot(x='Year', y='Gas Price', kind='line')
# plt.title('Gas Prices Over Time')
# plt.xlabel('Year')
# plt.ylabel('Gas Price ($/gallon)')

# Create a line plot of gas prices versus year
df_gas_prices.plot(x='Year', y='USA', kind='line')
plt.title('Gas Prices Over Time')
plt.xlabel('Year')
plt.ylabel('Gas Price ($/gallon)')
plt.show()

# %% [markdown]
# # ⚽️ FIFA 🏟️
#
# Federation Internationale de Football Association

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

df = pd.read_csv('fifa_data.csv')

# df.head()

df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'ID',
#  'Name',
#  'Age',
#  'Photo',
#  'Nationality',
#  'Flag',
#  'Overall',
#  'Potential',
#  'Club',
#  'Club Logo',
#  'Value',
#  'Wage',
#  'Special',
#  'Preferred Foot',
#  'International Reputation',
#  'Weak Foot',
#  'Skill Moves',
#  'Work Rate',
#  'Body Type',
#  'Real Face',
#  'Position',
#  'Jersey Number',
#  'Joined',
#  'Loaned From',
#  'Contract Valid Until',
#  'Height',
#  'Weight',
#  'LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB',
#  'Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
# ...

# %%
# Histogram of (1) column
# Because I wanna know the FREQUENCY of something
df['Age'].hist(bins=10)
plt.title('Histogram of Age')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Scatter plot
#
# A scatter plot is best used to show the relationship between two continuous variables and identify any patterns or clusters in the data.
#
# Scatter plots are particularly useful for visualizing the correlation between two variables, which can be positive, negative, or zero. They can also be used to identify clusters or patterns in the data.
#
# <mark>Note to self: come back to this.</mark>

# %%
import os
import sys

try:
    # Scatter plot (2) columns
    df.plot(x='Height', y='Weight', kind='scatter')
    plt.title('Scatter plot of Height vs Weight')
    plt.xlabel('Height')
    plt.ylabel('Weight')
    plt.show()
except Exception as e:
    exc_type, exc_obj, exc_tb = sys.exc_info()
    print("Line:", exc_tb.tb_lineno)
    print("Error:", exc_type, exc_obj)
# Out:
# Line: 6
# Error: <class 'TypeError'> 'value' must be an instance of str or bytes, not a float
